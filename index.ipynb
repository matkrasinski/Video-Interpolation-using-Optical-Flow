# %%
from lucas_kanade.lucas_kanade import lucas_kanade
from horn_schunck.horn_schunk import horn_schunk
import cv2

# %%
first_image = cv2.imread("vimeo_interp_test/input/00001/0389/im1.png", cv2.IMREAD_GRAYSCALE)
second_image = cv2.imread("vimeo_interp_test/input/00001/0389/im3.png", cv2.IMREAD_GRAYSCALE)

# %%
lk_flow, lk_gradients = lucas_kanade(firstImage=first_image, secondImage=second_image, N=2, dataset="vimeo", image_ind=1)

# %%
hs_flow, hs_gradients = horn_schunk(firstImage=first_image, secondImage=second_image, lambada=0.01, num_iter=1000, image_ind="1_horn-schunk", dataset="vimeo")
